# %% [markdown]
# # SetUp

# %%
# Modules used
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# File Paths and Settings
csv_path = "src-gen"  # relative path to the folder, where the csv files are located
aircraft_csv_path = os.path.join(csv_path, "Aircraft.csv")
pilot_csv_path = os.path.join(csv_path, "Pilot.csv")
atc_csv_path = os.path.join(csv_path, "AirTrafficController.csv")

# %% [markdown]
# # Analyzing Aircraft.csv

# %%
# General SetUp
col_not_for_plot = ["Tick", "Step", "0_Position", "1_Position", "ID", "Latitude", "Longitude", "Aircraft__callsign", "DateTime"]

# %%
with open(aircraft_csv_path, encoding='utf-8-sig') as file:
    df_aircraft = pd.read_csv(file, sep=";")
df_aircraft.head()
# Out:
#   Tick,Step,DateTime,Aircraft__acceleration_x,Aircraft__acceleration_z,Aircraft__angle_of_attack,Aircraft__callsign,Aircraft__climb_angle,Aircraft__drag,Aircraft__drag_coefficient,Aircraft__flight_phase,Aircraft__ground_speed_x,Aircraft__heading_bearing,Aircraft__height,Aircraft__lift,Aircraft__lift_coefficient,Aircraft__pitch,Aircraft__rate_of_climb,Aircraft__true_air_speed,Aircraft__true_air_speed_x,Brake__deceleration_application,Brake__deceleration_force,Brake__parking_brake,CIP__master_switch,Engine__failure,Engine__failure_probability,Engine__fuel_consumption,Engine__ignition_switch,Engine__mixture_control,Engine__oil,Engine__oil_leakage,Engine__oil_pressure,Engine__oil_pump_condition,Engine__oil_temperature,Engine__power,Engine__RPM,Engine__running,Engine__throttle,event_info,Latitude,Longitude,LWT__fuel_quantity,LWT__water_sediments,Propeller__thrust,Propeller__thrust_coefficient,RWT__fuel_quantity,RWT__water_sediments,Tire__friction_force,0_Position,1_Position,ID
# 0  0,0,2020-01-01T19:00:00.0000000+01:00,0,0,0,Ce...
# 1  0,0,2020-01-01T19:00:00.0000000+01:00,0,0,0,Ce...
# 2  0,0,2020-01-01T19:00:00.0000000+01:00,0,0,0,Ce...
# 3  0,0,2020-01-01T19:00:00.0000000+01:00,0,0,0,Ce...
# 4  0,0,2020-01-01T19:00:00.0000000+01:00,0,0,0,Ce...

# %%
#Generate List with column names
cols_to_plot = list(set(df_aircraft.columns)^set(col_not_for_plot))
cols_to_plot = sorted(cols_to_plot)
cols_to_plot
# Out:
# ['0_Position',
#  '1_Position',
#  'Aircraft__callsign',
#  'DateTime',
#  'ID',
#  'Latitude',
#  'Longitude',
#  'Step',
#  'Tick',
#  'Tick,Step,DateTime,Aircraft__acceleration_x,Aircraft__acceleration_z,Aircraft__angle_of_attack,Aircraft__callsign,Aircraft__climb_angle,Aircraft__drag,Aircraft__drag_coefficient,Aircraft__flight_phase,Aircraft__ground_speed_x,Aircraft__heading_bearing,Aircraft__height,Aircraft__lift,Aircraft__lift_coefficient,Aircraft__pitch,Aircraft__rate_of_climb,Aircraft__true_air_speed,Aircraft__true_air_speed_x,Brake__deceleration_application,Brake__deceleration_force,Brake__parking_brake,CIP__master_switch,Engine__failure,Engine__failure_probability,Engine__fuel_consumption,Engine__ignition_switch,Engine__mixture_control,Engine__oil,Engine__oil_leakage,Engine__oil_pressure,Engine__oil_pump_condition,Engine__oil_temperature,Engine__power,Engine__RPM,Engine__running,Engine__throttle,event_info,Latitude,Longitude,LWT__fuel_quantity,LWT__water_sediments,Propeller__thrust,Propeller__thrust_coefficient,RWT__fuel_quantity,RWT__water_sediments,Tire__friction_force,0_Position,1_Position,ID']

# %% [markdown]
# ## Plot of all procuded Signals from Aircraft

# %%
fig, axs = plt.subplots(len(cols_to_plot), figsize=(12, 8*len(cols_to_plot)))
df_grouped_aircraft = df_aircraft.groupby('Aircraft__callsign')

for count, col in enumerate(cols_to_plot):
    for key, group in df_grouped_aircraft:
        axs[count].plot(group["Step"], group[col], label = key)
        axs[count].set(xlabel = "Step", ylabel = col)
        axs[count].legend()
        axs[count].grid(linestyle='-', linewidth=0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-683849cb9c77> in <module>
#       1 fig, axs = plt.subplots(len(cols_to_plot), figsize=(12, 8*len(cols_to_plot)))
# ----> 2 df_grouped_aircraft = df_aircraft.groupby('Aircraft__callsign')
#       3
#       4 for count, col in enumerate(cols_to_plot):
#       5     for key, group in df_grouped_aircraft:
#
# c:\users\eriks\desktop\githubrepo\machine_learning\machinelearningvenv\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# c:\users\eriks\desktop\githubrepo\machine_learning\machinelearningvenv\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# c:\users\eriks\desktop\githubrepo\machine_learning\machinelearningvenv\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
#     390                 observed=observed,
# --> 391                 mutated=self.mutated,
#     392             )
#     393
#
# c:\users\eriks\desktop\githubrepo\machine_learning\machinelearningvenv\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     619                 in_axis, name, level, gpr = False, None, gpr, None
#     620             else:
# --> 621                 raise KeyError(gpr)
#     622         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     623             # Add key to exclusions
#
# KeyError: 'Aircraft__callsign'

# %% [markdown]
# ## Plot of Latitude, Longitude and height

# %%
# Only useful with one aircraft so far
df_aircraft_c = df_aircraft[df_aircraft["Longitude"] != 9.4] # filter out default values
fig = plt.figure(figsize=(15, 10))
ax = plt.scatter(df_aircraft_c["Longitude"], df_aircraft_c["Latitude"],s=1, c=df_aircraft_c["Aircraft__height"], cmap=plt.cm.coolwarm)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
cb = plt.colorbar(ax)
cb.set_label('Height[m]')

# %% [markdown]
# # Analyzing Pilot.csv

# %%
with open(pilot_csv_path, encoding='utf-8-sig') as file:
    df_pilot = pd.read_csv(file, sep=";")
df_pilot.head()

# %%
cols_to_plot2 = ["current_activity", "state", "event_info", "takeoff_distance"]
df_grouped_pilot = df_pilot.groupby('myAircraft_callsign')

fig, axs = plt.subplots(len(cols_to_plot2), figsize=(12, 8*len(cols_to_plot2)))

for count, col in enumerate(cols_to_plot2):
    for key, group in df_grouped_pilot:
        axs[count].plot(group["Tick"], group[col], label = key)
        axs[count].set(xlabel = "Tick", ylabel = col)
        axs[count].legend()
        axs[count].grid(linestyle='-', linewidth=0.5)

# %% [markdown]
# # Analyzing AirTrafficController.csv

# %%
with open(atc_csv_path, encoding='utf-8-sig') as file:
    df_atc = pd.read_csv(file, sep=";")
df_atc.head()

# %%
cols_to_plot3 = ["callsign_received", "state", "message_type_received"]
df_atc = df_atc.replace(np.nan, 'None', regex=True)
#df_atc.head()

# %%
fig, axs = plt.subplots(len(cols_to_plot3), figsize=(12, 8*len(cols_to_plot3)))

for count, col in enumerate(cols_to_plot3):
    axs[count].plot(df_atc["Tick"], df_atc[col])
    axs[count].set(xlabel = "Tick", ylabel = col)
    axs[count].grid(linestyle='-', linewidth=0.5)
